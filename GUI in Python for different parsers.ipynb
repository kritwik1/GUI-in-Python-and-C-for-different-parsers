# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'nae.ui'
#
# Created by: PyQt5 UI code generator 5.13.0
#
# WARNING! All changes made in this file will be lost!


from PyQt5 import QtCore, QtGui, QtWidgets
import os

class Ui_Dialog(object):
    def setupUi(self, Dialog):
        Dialog.setObjectName("Dialog")
        Dialog.resize(1065, 683)
        self.pushButton = QtWidgets.QPushButton(Dialog)
        self.pushButton.setGeometry(QtCore.QRect(50, 230, 161, 31))
        self.pushButton.setObjectName("pushButton")
        self.pushButton.clicked.connect(self.recursion)
        self.label = QtWidgets.QLabel(Dialog)
        self.label.setGeometry(QtCore.QRect(10, 10, 91, 31))
        self.label.setObjectName("label")
        self.textEdit = QtWidgets.QTextEdit(Dialog)
        self.textEdit.setGeometry(QtCore.QRect(110, 20, 891, 161))
        self.textEdit.setObjectName("textEdit")
        self.textEdit_2 = QtWidgets.QTextEdit(Dialog)
        self.textEdit_2.setGeometry(QtCore.QRect(60, 370, 891, 161))
        self.textEdit_2.setObjectName("textEdit_2")
        self.pushButton_2 = QtWidgets.QPushButton(Dialog)
        self.pushButton_2.setGeometry(QtCore.QRect(260, 230, 181, 31))
        self.pushButton_2.setObjectName("pushButton_2")
        self.pushButton_2.clicked.connect(self.factoring)
        self.pushButton_3 = QtWidgets.QPushButton(Dialog)
        self.pushButton_3.setGeometry(QtCore.QRect(510, 230, 141, 28))
        self.pushButton_3.setObjectName("pushButton_3")
        self.pushButton_3.clicked.connect(self.fnf)
        self.pushButton_4 = QtWidgets.QPushButton(Dialog)
        self.pushButton_4.setGeometry(QtCore.QRect(702, 230, 121, 28))
        self.pushButton_4.setObjectName("pushButton_4")
        self.pushButton_4.clicked.connect(self.rd)
        self.pushButton_5 = QtWidgets.QPushButton(Dialog)
        self.pushButton_5.setGeometry(QtCore.QRect(900, 230, 93, 28))
        self.pushButton_5.setObjectName("pushButton_5")
        self.pushButton_4.clicked.connect(self.slr)

        self.retranslateUi(Dialog)
        QtCore.QMetaObject.connectSlotsByName(Dialog)

    def retranslateUi(self, Dialog):
        _translate = QtCore.QCoreApplication.translate
        Dialog.setWindowTitle(_translate("Dialog", "Dialog"))
        self.pushButton.setText(_translate("Dialog", "Left Recursion"))
        self.label.setText(_translate("Dialog", "Grammar"))
        self.pushButton_2.setText(_translate("Dialog", "Left Factoring"))
        self.pushButton_3.setText(_translate("Dialog", "First and follow"))
        self.pushButton_4.setText(_translate("Dialog", "Recursive Descent"))
        self.pushButton_5.setText(_translate("Dialog", "SLR"))
    def recursion(self):
        input_set = self.textEdit.toPlainText().split()
        a=[]
        s=""
        n=len(input_set)
        for i in input_set:
            j=i.split('->')
            a.append(j)
        for i in range(n):
            if(a[i][0]==(a[i][1])[0] ):
                l=a[i][0]
                w=(a[i][1])[1:]
                for i in range(i+1,n):
                    if(a[i][0]==l):
                        z=a[i][1]
                        s=s+l+"->"+z+l+"'\n"
                        s=s+l+"'"+"->"+w+l+"'"+"/"+"epsilon"
        
        self.textEdit_2.setText(s)
    def fnf(self):
        def follow(ter,nter,key,d,ss):
            fol=[]

            for k in d:
                jay=1
                if key==ss:
                    fol.append('$')

                if k!=key:
                    #print "k="+k
                    #print "key"+key
                    temp=d[k]
                    #print temp
                    for i in range(0,len(temp)):
                        v=0
                        for j in range(0,len(temp[i])):
                            if temp[i][j]==key:
                                #print temp[i]
                                if len(temp[i])>j+1:
                                    if temp[i][j+1] in ter:
                                        fol.append(temp[i][j+1])
                                    elif temp[i][j+1] in nter:
                                        for z in first(ter,nter,temp[i][j+1],d):
                                            if z!='!':
                                                fol.append(z)
                                            else:
                                                v=1
                                                while(jay!=0):
                                                    #print v
                                                    if(len(temp[i])>j+v+1):
                                                        #print temp[i][j+v+1]
                                                        #print len(temp[i])
                                                        #print v+j+1
                                                        if temp[i][j+v+1] in ter:
                                                            fol.append(temp[i][j+v+1])

                                                        else:
                                                            for q in first(ter,nter,temp[i][j+v+1],d):

                                                                if q!='!':
                                                                    fol.append(q)
                                                            if "!" not in first(ter,nter,temp[i][j+v+1],d):
                                                                jay=0
                                                                #print "a"
                                                            else:
                                                                v=v+1
                                                    else:
                                                        flag=0
                                                        #print "in"
                                                        for p in follow(ter,nter,k,d,ss):
                                                            fol.append(p)



                                else:
                                    for z in follow(ter,nter,k,d,ss):
                                        fol.append(z)
            return fol

        def first(ter,nter,key,d):
            temp=d[key]
            f=[]
            y=0
            jay=1
            for i in range(len(temp)):
                if temp[i][y] in ter or temp[i][y]=="!" and temp[i][y] not in f:
                    f.append(temp[i][0])
                if temp[i][y]=="!" and len(temp[i])==y+1:
                    f.append("!")
                elif temp[i][y] in nter:
                    while jay!=0 and len(temp[i])>y:
                        if temp[i][y] in ter:
                            f.append(temp[i][y])
                            break
                        for j in (first(ter,nter,temp[i][y],d)):
                            if j not in f and j!="!":
                                f.append(j)
                            if j=="!"  and len(temp[i])==y+1:
                                f.append("!")

                        if "!" in (first(ter,nter,temp[i][y],d)) :
                            y=y+1
                        else:
                            jay=0

                    y=0

            return f
        s=""
        arr=[]
        ter=[]
        nter=[]
        input_set = self.textEdit.toPlainText().split()
        ss=input_set[0][0]
        print(ss)
        n=len(input_set)
        for i in set(input_set):
            for j in i:
                if j.isupper():
                    nter.append(j)
                elif j.islower():
                    ter.append(j)
        arr=input_set
        d=dict()
        for i in range(0,len(arr)):
            d[arr[i][0]]=''
        for key in d:
            t=[]
            for i in range(0,len(arr)):
                if(arr[i][0]==key):
                    t.append(arr[i][3:len(arr[i])+1])
            d[key]=t
        for i in range(0,n):
            if arr[i][0] not in nter:
                nter.append(arr[i][0])
        for i in range(0,n):
            for j in range(0,len(arr[i])):
                if(arr[i][j] not in nter and arr[i][j]!="-" and arr[i][j]!=">" and arr[i][j] not in ter and arr[i][j]!="!" ):
                    ter.append(arr[i][j])
        for x in set(nter):
            l=first(ter,nter,x,d)
            s=s+"first of "+x+" is: "
            s=s+" ".join(list(set(l)))+"\n"
            #self.textEdit_2.setText(s)
        for x in set(nter):
            l=follow(ter,nter,x,d,ss)
            s=s+"Follow of "+x+" is: "
            s=s+" ".join(list(set(l)))+"\n"
            self.textEdit_2.setText(s)
    def factoring(self):
        s=""
        input_set = self.textEdit.toPlainText().split()
        pro=input_set
        n=len(input_set)
        a=[]
        mn=100
        for item in pro:
            if len(item)<=mn:
                mn=len(item)
                index=pro.index(item)

        v=pro[index]
        lr=[]
        dictionary={}

        for value in pro:
            if index!=pro.index(value):
                ide=3
                flag=0
                for i in range(3,mn):
                    if v[i]!=value[i]:
                        dictionary[pro.index(value)]=ide-1
                        flag=1
                        break
                    else:
                        ide+=1

                if flag==0:
                    dictionary[pro.index(value)]=ide-1

        mnc=100
        for key in dictionary.keys():
            if dictionary[key]<=mnc:
                mnc=dictionary[key]

        for value in pro:
            if index!=pro.index(value):
                lr.append(value[0]+"'->"+value[mnc+1:])
            elif index==pro.index(value):
                lr.append(value[0]+"->"+value[3:mnc+1]+value[0]+"'")
                if mnc+1==mn:
                    lr.append(value[0]+"'->"+"!")
                else:
                    lr.append(value[0]+"'->"+value[mnc+1:])
        ans=[]
        for i in lr:
            if i.index("'")==len(i)-1:
                ans.append(i)
                id2=lr.index(i)
        for i in range(len(lr)):
            if id2!=i:
                ans.append(lr[i])
        s="\n".join(ans)
        self.textEdit_2.setText(s)
    def rd(self):
        s=""
        def E():
            global a
            T()
            Ed()
            if pointer=='$':
                a+=1

        def T():
            F()
            Td()

        def Ed():
            global b
            if pointer=='+':
                b=1
                match()
                T()
                Ed()

        def Td():
            global b,c
            if(pointer=='*'):
                c=1
                if(b==0):
                    match()
                    F()
                    Td()

        def F():
            global b,c,d
            if(pointer=='('):
                b=0
                c=0
                d=1
                match()
                E()
                if pointer==')':
                    d=0
                    match()
            else:
                if pointer=='i':
                    b=0
                    c=0
                    match()
                    if(pointer=='d'):
                        match()



        def match():
            global i
            i=i+1
            global pointer
            pointer=inp[i]
        global inp
        inp = self.textEdit.toPlainText()
        global i,a,b,c,d
        i=0
        global pointer
        pointer=inp[i]
        a=-1
        b=0
        c=0
        d=0
        E()
        if a!=-1 and c==0 and b==0 and d==0:
            s="String is acceptable"
            #print("String is acceptable\n")
        else:
            s="String is unacceptable"
            #print("String is unacceptable\n")  
        self.textEdit_2.setText(s)
    def slr(self):
        
if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Dialog = QtWidgets.QDialog()
    ui = Ui_Dialog()
    ui.setupUi(Dialog)
    Dialog.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\Ritwik\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3275: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
